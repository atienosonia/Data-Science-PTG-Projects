# %%
import pandas as pd

# %%
bom_movies = pd.read_csv(r'C:\Users\user\Documents\ptg-projects\dsc-phase-1-project-v2-4\Data\bom.movie_gross.csv')
bom_movies.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
movie_info = pd.read_csv(r'C:\Users\user\Documents\ptg-projects\dsc-phase-1-project-v2-4\Data\rt.movie_info.tsv', sep = '\t')
movie_info.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# ...

# %%
tmdb_movies = pd.read_csv(r'C:\Users\user\Documents\ptg-projects\dsc-phase-1-project-v2-4\Data\tmdb.movies.csv', index_col = 0)
tmdb_movies
# Out:
#                  genre_ids      id original_language  \
# 0          [12, 14, 10751]   12444                en
# 1      [14, 12, 16, 10751]   10191                en
# 2            [12, 28, 878]   10138                en
# 3          [16, 35, 10751]     862                en
# 4            [28, 878, 12]   27205                en
# ...                    ...     ...               ...
# 26512             [27, 18]  488143                en
# 26513             [18, 53]  485975                en
# 26514         [14, 28, 12]  381231                en
# 26515      [10751, 12, 28]  366854                en
# 26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# ...

# %%
movies_budget = pd.read_csv(r'C:\Users\user\Documents\ptg-projects\dsc-phase-1-project-v2-4\Data\tn.movie_budgets.csv')
movies_budget.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
# Merge the two dataframes, bom_movies_df and movie_budgets_df and display the merged dataframe
merged_df = pd.merge(bom_movies, movies_budget, how='inner', left_on='title', right_on='movie')
merged_df.head()
# Out:
#                         title studio  domestic_gross_x foreign_gross  year  \
# 0                 Toy Story 3     BV       415000000.0     652000000  2010
# 1                   Inception     WB       292600000.0     535700000  2010
# 2         Shrek Forever After   P/DW       238700000.0     513900000  2010
# 3  The Twilight Saga: Eclipse   Sum.       300500000.0     398000000  2010
# 4                  Iron Man 2   Par.       312400000.0     311500000  2010
#
#    id  release_date                       movie production_budget  \
# 0  47  Jun 18, 2010                 Toy Story 3      $200,000,000
# 1  38  Jul 16, 2010                   Inception      $160,000,000
# 2  27  May 21, 2010         Shrek Forever After      $165,000,000
# 3  53  Jun 30, 2010  The Twilight Saga: Eclipse       $68,000,000
# 4  15   May 7, 2010                  Iron Man 2      $170,000,000
#
#   domestic_gross_y worldwide_gross
# 0     $415,004,880  $1,068,879,522
# 1     $292,576,195    $835,524,642
# ...

# %%
merged_df.columns
# Out:
# Index(['title', 'studio', 'domestic_gross_x', 'foreign_gross', 'year', 'id',
#        'release_date', 'movie', 'production_budget', 'domestic_gross_y',
#        'worldwide_gross'],
#       dtype='object')

# %%
merged_df.drop('domestic_gross_y', axis = 1, inplace = True)

# %%
merged_df
# Out:
#                            title studio  domestic_gross_x foreign_gross  year  \
# 0                    Toy Story 3     BV       415000000.0     652000000  2010
# 1                      Inception     WB       292600000.0     535700000  2010
# 2            Shrek Forever After   P/DW       238700000.0     513900000  2010
# 3     The Twilight Saga: Eclipse   Sum.       300500000.0     398000000  2010
# 4                     Iron Man 2   Par.       312400000.0     311500000  2010
# ...                          ...    ...               ...           ...   ...
# 1242                       Gotti     VE         4300000.0           NaN  2018
# 1243                 Ben is Back  RAtt.         3700000.0           NaN  2018
# 1244  Bilal: A New Breed of Hero     VE          491000.0       1700000  2018
# 1245                       Mandy    RLJ         1200000.0           NaN  2018
# 1246                Lean on Pete    A24         1200000.0           NaN  2018
#
# ...

# %%
merged_df.rename(columns = {'domestic_gross_x' : 'domestic_gross'}, inplace = True)

# %%
merged_df
# Out:
#                            title studio  domestic_gross foreign_gross  year  \
# 0                    Toy Story 3     BV     415000000.0     652000000  2010
# 1                      Inception     WB     292600000.0     535700000  2010
# 2            Shrek Forever After   P/DW     238700000.0     513900000  2010
# 3     The Twilight Saga: Eclipse   Sum.     300500000.0     398000000  2010
# 4                     Iron Man 2   Par.     312400000.0     311500000  2010
# ...                          ...    ...             ...           ...   ...
# 1242                       Gotti     VE       4300000.0           NaN  2018
# 1243                 Ben is Back  RAtt.       3700000.0           NaN  2018
# 1244  Bilal: A New Breed of Hero     VE        491000.0       1700000  2018
# 1245                       Mandy    RLJ       1200000.0           NaN  2018
# 1246                Lean on Pete    A24       1200000.0           NaN  2018
#
# ...

# %%
merged_df.isna().sum()
# Out:
# title                  0
# studio                 1
# domestic_gross         2
# foreign_gross        161
# year                   0
# id                     0
# release_date           0
# movie                  0
# production_budget      0
# worldwide_gross        0
# dtype: int64

# %%
merged_df.to_csv('movies_data.csv')
